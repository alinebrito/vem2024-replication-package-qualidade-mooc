# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 

def plot_violin(dataset, y_label, x_label, name_fig):
  plt.figure(figsize = (5, 10))
  # plt.xlim(2, 500)
  # plt.xticks([9, 100, 1000])
  plt.yticks([1000, 10000, 20000, 40000, 100000])
  #plt.yscale('log')
  sns.set(style="darkgrid")#ggplot whitegrid
  #ax = sns.violinplot(y=df["sepal_length"], palette='Paired', color = 'black')
  ax = sns.violinplot(x=x_label, y=y_label, data=dataset, color='blue', linewidth=2, saturation=0.12)
  sns.set_context("talk")
  sns.set(style="whitegrid")
  sns.violinplot()
  
  # plt.tight_layout(pad=0.05)

  plt.savefig(name_fig)
  plt.show()
  pass

#Distribuição do tamanho dos composite refactorings por projeto
dataset=pd.read_csv('language_loc_alura.csv', delimiter=",")
plot_violin(dataset, "lines_of_code", "language", "fig_students_violin_graph.pdf")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import importlib
importlib.reload(plt); importlib.reload(pd); importlib.reload(sns)

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(3.5, 2))
ax.set_yscale("log")

formatter = ScalarFormatter()
plt.gca().yaxis.set_major_formatter(formatter)

# Load the example planets dataset
dataframe = pd.read_csv("language_loc_alura.csv", encoding="ISO-8859-1", delimiter=",")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="language", y="lines_of_code", data=dataframe, width=.7, linewidth=1.0, palette="Blues")
# Add in points to show each observation
sns.stripplot(x="language", y="lines_of_code", data=dataframe,
              size=3, color="silver", linewidth=0.5)

# personalizar os yticks
yticks = [10, 100, 1000, 10000]
yticks_str = ['10', '100', '1k', '10k']
plt.yticks(yticks, yticks_str)
sns.set(font_scale=.8)
sns.set_style("whitegrid")
plt.minorticks_off()
ax.yaxis.grid(True)
ax.set(ylabel="Linhas de Código", xlabel="")
plt.savefig("loc_alura.pdf",bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd

# sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(3.5, 2))
ax.set_yscale("log")

formatter = ScalarFormatter()
plt.gca().yaxis.set_major_formatter(formatter)
plt.gca().yaxis.set_minor_formatter(plt.NullFormatter())

# Load the example planets dataset
dataframe = pd.read_csv("language_loc_udacity.csv", encoding="ISO-8859-1", delimiter=",")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="language", y="lines_of_code", data=dataframe, width=.7, linewidth=1.0, palette="Greens")
# Add in points to show each observation
sns.stripplot(x="language", y="lines_of_code", data=dataframe,
              size=3, color="silver", linewidth=0.5)

ax.axis('tight')
plt.minorticks_off()
# Tweak the visual presentation
yticks = [10, 100, 1000, 10000, 100000]
yticks_str = ['10', '100', '1k', '10k', '100k']
plt.yticks(yticks, yticks_str)
sns.set(font_scale=.8)
sns.set_style("whitegrid")
ax.yaxis.grid(True)
ax.set(ylabel="Linhas de Código", xlabel="")
plt.savefig("loc_udacity.pdf",bbox_inches='tight')
# sns.despine(trim=True, left=True)

# %%
import seaborn as sns
import pandas as pd

# Criando um DataFrame com valores categóricos A, B, C, D, E e valores numéricos
data = pd.DataFrame({
    'Code Smell': ['A', 'B', 'B', 'C', 'C', 'C', 'D', 'D', 'E'],
    'Bug': ['A', 'A', 'B', 'C', 'D', 'D', 'D', 'D', 'E'],
    'Valor': ['Code Smell', 'Bug', 'Code Smell', 'Bug', 'Bug', 'Bug', 'Code Smell','Bug'],

})

# Criando um boxplot categorizado com Seaborn
sns.boxplot(x='Valor', y='Categoria', data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b968840d54fb> in <module>
#       3
#       4 # Criando um DataFrame com valores categóricos A, B, C, D, E e valores numéricos
# ----> 5 data = pd.DataFrame({
#       6     'Code Smell': ['A', 'B', 'B', 'C', 'C', 'C', 'D', 'D', 'E'],
#       7     'Bug': ['A', 'A', 'B', 'C', 'D', 'D', 'D', 'D', 'E'],
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ...

# %% [markdown]
# # Nova seção

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataframe = pd.read_csv("/content/dataset.csv", encoding="ISO-8859-1", delimiter=";")
language = dataframe.language
student_count = dataframe.student_count
rating = dataframe.rating
sns.set(rc={'figure.figsize':(13,5.27)})

sns.set_style("whitegrid")
ax = sns.violinplot(x=language, y=rating, cut = 0)
ax.set(xlabel='Linguagem', ylabel='Avaliacoes')
plt.savefig("avaliacao_x_linguagem.pdf")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataframe = pd.read_csv("language_loc_alura.csv", encoding="ISO-8859-1", delimiter=",")
language = dataframe.language
lines_of_code = dataframe.lines_of_code
sns.set(rc={'figure.figsize':(6,2.5)})

sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=0.8)
ax = sns.violinplot(x=language, y=lines_of_code, linewidth=0.9)
ax.set(ylabel='Linhas de Código')
plt.yticks([0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000])
plt.savefig("linguagem_x_loc.pdf")

# plt.yscale('log')
# plt.ylim(0, 10000)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

dataframe = pd.read_csv("language_loc.csv", encoding="ISO-8859-1", delimiter=",")

data = {
    'Plataforma': ['Alura'] * 162 + ['Udacity'] * 190,
    'Linguagem': dataframe['language'],
    'Linhas de código': dataframe['lines_of_code']
}

print(len(data['Plataforma']))
print(len(data['Linguagem']))
print(len(data['Linhas de código']))

df = pd.DataFrame(data)

sns.set(style="whitegrid")

# plt.yscale('log')
plt.ylim(0, 1000)

ax = sns.violinplot(x="Linguagem", y="Linhas de código", hue="Plataforma", data=df, split=True, inner="quartile")

plt.show()
# Out:
# 352
# 352
# 352

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataframe = pd.read_csv("cursos_x_issues2.csv", encoding="ISO-8859-1", delimiter=";")
types = dataframe.types
count = dataframe.count
sns.set(rc={'figure.figsize':(8,5)})

sns.set_style("whitegrid")
ax = sns.violinplot(x=dataframe["types"], y=dataframe["count"])
ax.set(xlabel='types', ylabel='count')
plt.yscale('log')
plt.savefig("avaliacao_x_linguagem.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ce74d07083cb> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 dataframe = pd.read_csv("cursos_x_issues2.csv", encoding="ISO-8859-1", delimiter=";")
#       6 types = dataframe.types
#       7 count = dataframe.count
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
 
# Generating dataset of random numbers
dataframe = pd.read_csv("cursos_x_issues_code_smells.csv", encoding="ISO-8859-1", delimiter=";")
plt.subplots(figsize=(3, 2.5))
plt.xlim(xmin=0, xmax = 200)
plt.gca().set_yscale("log")
formatter = ScalarFormatter()
formatter.set_powerlimits((-3, 0))
plt.gca().yaxis.set_major_formatter(formatter)
plt.gca().yaxis.set_minor_formatter(plt.NullFormatter())
plt.yticks([0, 1, 3, 5, 10, 20, 40, 100, 200], ['0', '1', '3', '5', '10', '20', '40', '100', '200'])

# Plot histogram
ax = sns.histplot(data = dataframe, x = "count", bins=170)
# sns.set_context("notebook", font_scale=0.45)
ax.set_xlabel("Quantidade de Code Smells")
ax.set_ylabel("Quantidade de Cursos")
# Out:
# Text(0, 0.5, 'Quantidade de Cursos')

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# import numpy as np
#
# dataframe = pd.read_csv("dataset2.csv", encoding="ISO-8859-1", delimiter="\t")
# df_sz = pd.DataFrame({'Code Smells': dataframe['code_smells_count'].astype(int),
#                       'Bugs': dataframe['bugs_count'].astype(int),
#                       'Vulnerabilidades': dataframe['vulnerability_count'].astype(int)})
#
# fig, ax = plt.subplots(figsize=(10, 4)) # very wide figure to accomodate 200 bars
# sns.histplot(data=df_sz.melt(), x='value', stat = "frequency", hue='variable',
#              alpha=0.7, shrink=0.3, multiple='dodge', ax=ax)
# ax.legend_.set_title('') # remove the legend title (the name of the hue column)
# ax.margins(x=0.1) # less spacing
#
# plt.xlim(xmin=0, xmax = 100)
# plt.yscale('log')
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

dataframe = pd.read_csv("dataset2.csv", encoding="ISO-8859-1", delimiter="\t")
df_sz = pd.DataFrame({'Code Smells': dataframe['code_smells_count'].astype(int),
                      'Bugs': dataframe['bugs_count'].astype(int),
                      'Vulnerabilidades': dataframe['vulnerability_count'].astype(int)})

fig, ax = plt.subplots(figsize=(6, 3)) # very wide figure to accomodate 200 bars
sns.histplot(data=df_sz.melt(), x='value', stat = "frequency", hue='variable', bins=40,
             alpha=0.7, shrink=0.3, multiple='dodge', ax=ax)
ax.legend_.set_title('') # remove the legend title (the name of the hue column)
ax.margins(x=0.1) # less spacing

plt.xlim(xmin=0, xmax = 100)
plt.yscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Crie um dataframe a partir dos seus dados
dados = {'Curso': ['Curso A', 'Curso B', 'Curso C', 'Curso D', 'Curso A', 'Curso B', 'Curso C', 'Curso D'],
         'Code Smells': [50, 30, 20, 40,50, 30, 20, 40],
         'Bugs': [10, 20, 30, 40,50, 30, 20, 40],
         'Vulnerabilidades': [5, 15, 25, 35,50, 30, 20, 40]}
df = pd.DataFrame(dados)

# Crie um gráfico de barras
fig, ax = plt.subplots()
ax.bar(df.index, df['Code Smells'], label='Code Smells')
ax.bar(df.index, df['Bugs'], bottom=df['Code Smells'], label='Bugs')
ax.bar(df.index, df['Vulnerabilidades'], bottom=df['Code Smells']+df['Bugs'], label='Vulnerabilidades')

# Adicione rótulos e legendas
ax.set_ylabel('Número de Problemas')
ax.set_title('Frequência de Cursos e Seus Números de Problemas')

# Exiba o gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(8, 5))
ax.set_yscale("log")

# Load the example planets dataset
dataframe = pd.read_csv("cursos_x_issues2.csv", encoding="ISO-8859-1", delimiter=";")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="types", y="count", data=dataframe, width=.5, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="types", y="count", data=dataframe,
              size=3, color=".4", linewidth=0,)

# plt.ylim(0, 1300)

# Tweak the visual presentation
# ax.xaxis.grid(True)
# ax.set(ylabel="")
# sns.despine(trim=True, left=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='types', ylabel='count'>

# %%
# Import required libraries
import pandas as pd
  
# Create a sample dataframe
df = pd.DataFrame({'Tipo de Problema': ['Code Smell', 'Bug', 'Vulnerabilidade'],
                   'Quantidade': [20, 25, 15]})
  
# Plot a bar chart
df.plot.barh(x='Tipo de Problema', y='Quantidade',
             title='Java', color='green')
# Out:
# <Axes: title={'center': 'Java'}, ylabel='Tipo de Problema'>

# %%
# RQ.1 - Java (v1)
import pandas as pd
  
Alura = [420, 54, 0]
Udacity = [3309, 43, 1]
index = ['Code Smell', 'Bug', 'Vulnerabilidade']
df = pd.DataFrame({'Alura': Alura,
                   'Udacity': Udacity}, index=index)
ax = df.plot.barh(stacked=True)

labels = [i for i in df.to_numpy().flatten(order='F')]

for i, patch in enumerate(ax.patches):
    x, y = patch.get_xy()
    x += patch.get_width() / 2
    y += patch.get_height() / 2
    ax.annotate(labels[i], (x, y), ha='center', va='center', c='black')

# %%
# RQ.1 - Java (v1)
import pandas as pd
  
Alura = [52, 17, 14]
Udacity = [48, 24, 70]
index = ['Code Smell', 'Bug', 'Vulnerabilidade']
df = pd.DataFrame({'Alura': Alura,
                   'Udacity': Udacity}, index=index)
ax = df.plot.barh(stacked=True, title='Java')

labels = [f'{i}\n({i/2:.0%})' for i in df.to_numpy().flatten(order='F')]

for i, patch in enumerate(ax.patches):
    x, y = patch.get_xy()
    x += patch.get_width() / 2
    y += patch.get_height() / 2
    ax.annotate(labels[i], (x, y), ha='center', va='center', c='black')

# %%
# RQ.1 - Java (v1)
import pandas as pd
  
Alura = [1266, 114, 18]
Udacity = [6389, 328, 12]

index = ['Code Smell', 'Bug', 'Vulnerabilidade']
df = pd.DataFrame({'Alura': Alura,
                   'Udacity': Udacity}, index=index)
totals = df.sum(axis=1)

# calculate the percent for each row
percent = df.div(totals, axis=0).mul(100).round(2)

# create the plot
ax = percent.plot(kind='barh', stacked=True, figsize=(9, 5), color=['green', 'gray'], xticks=[])
# move the legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=2, frameon=False)

# remove ticks
ax.tick_params(left=False, bottom=False)
# remove all spines
ax.spines[['top', 'bottom', 'left', 'right']].set_visible(False)


# iterate through each container
for c in ax.containers:
    
    # custom label calculates percent and add an empty string so 0 value bars don't have a number
    labels = [f'{w}\n{w:0.2f}%' if (w := v.get_width()) > 0 else '' for v in c]
    
    # add annotations
    ax.bar_label(c, labels=labels, label_type='center', padding=0.3, color='w')

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
import pandas as pd


Alura = [42, 54, 22]
Udacity = [39, 43, 34]

issues = ['Code Smells', 'Bugs', 'Vulnerabilidades']

df3 = pd.DataFrame(data={}, index=issues)
# df3 = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)

df = pd.DataFrame({'Alura': list_1, 'Udacity': list_2})
sns.set(style='white')
fig, ax = plt.subplots(figsize=(10, 2))
sns.histplot(data=df.melt(var_name='Dataset', value_name='Value'), y='Value', hue='Dataset',
             stat='percent', multiple='fill', discrete=True, shrink=0.9,
             palette=['tomato', 'limegreen', 'cornflowerblue'], alpha=1, ax=ax)
sns.despine()
sns.move_legend(ax, bbox_to_anchor=(1.01, 1.02), loc='upper left')
ax.set_yticks([0, 1])
ax.xaxis.set_major_formatter(PercentFormatter(1))
for p in ax.patches:
    h, w, x, y = p.get_height(), p.get_width(), p.get_x(), p.get_y()
    text = f'{w * 100:0.2f} %'
    ax.annotate(text=text, xy=(x + w / 2, y + h / 2), ha='center', va='center', color='white', size=16)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-6375275b6e1f>:18: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.histplot(data=df.melt(var_name='Dataset', value_name='Value'), y='Value', hue='Dataset',

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'Day': ['Code Smells', 'Bugs', 'Vulnerabilidades',
                           'Code Smells', 'Bugs', 'Vulnerabilidades'],
                   'Customers': [44, 46, 49,
                                 33, 46, 50],
                   'Time': ['Alura', 'Alura', 'Alura',
                            'Udacity', 'Udacity', 'Udacity']})


df['Customers (%)'] = df.groupby('Day')['Customers'].transform(lambda x: x / x.sum() * 100)

ax = sns.barplot(x='Day', y='Customers (%)', hue='Time', data=df) 

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f%%')

# %%
import pandas as pd
import matplotlib.pyplot as plt

issues = ['Code Smells', 'Bugs', 'Vulnerabilidades']

# df3 = pd.DataFrame(data={'Alura': [40, 54, 22], 'Udacity': [40, 43, 34]}, index=issues)
df3 = pd.DataFrame(data={'Alura': [1266, 114, 0], 'Udacity': [6389, 328, 12]}, index=issues)



ax = df3.plot(kind='barh', ylabel='Issues', title='Todas as Linguagens', log=True, width=0.8, figsize=(9,5))
ax.set(xlabel='No. de Issues em Log')


total  = df3.sum(axis=1)
# print(total)

for row, c, col in zip(df3.index, ax.containers, df3.columns):
    print(df3[col][row])
    ax.bar_label(c, label_type='center', labels=[f'{val}' for val in df3[col]])
    # ax.bar_label(c, label_type='center', labels=[f'{val}\n({val / total[0] * 100.0:.1f}%)' for val in df3[col]])

ax.legend(title='Plataforma', bbox_to_anchor=(0.9,1), loc='upper left')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)



plt.tight_layout()
# plt.figure(figsize=(10,40))
plt.savefig("total_issues_todas_linguagens.png")
plt.show()
# Out:
# 1266
# 328
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-3b124c582454> in <module>
#      28
#      29
# ---> 30 plt.tight_layout()
#      31 # plt.figure(figsize=(10,40))
#      32 plt.savefig("total_issues_todas_linguagens.png")
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2347 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2348 def tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None):
# -> 2349     return gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2350
#    2351
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3507             previous_engine = self.get_layout_engine()
#    3508             self.set_layout_engine(engine)
# -> 3509             engine.execute(self)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

issues = ['Code Smells', 'Bugs', 'Vulnerabilidades']

# dataframe sample data
java = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
python = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
go = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
javascript = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
typescript = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)

languages = [
              ['Java', 'Python'],
              ['Javascript', 'Typescript'],
              ['Go', '']
]

#define number of rows and columns for subplots
nrow=3
ncol=2

# make a list of all dataframes 
df_list = [java ,python, go, javascript,typescript]
fig, axes = plt.subplots(nrow, ncol)


# plot counter
count=0
for r in range(nrow):
    for column in range(ncol):


        if r == 3 and column == 2:
          axes[r][column].set_visible(False)

        ax = df_list[count].plot(ax=axes[r,column], kind='barh', title=languages[r][column], width=0.8, log=True, figsize=(12,9), legend=False)
        
        plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.4)
        count+=1
        for row, c, col in zip(df3.index, ax.containers, df3.columns):
          ax.bar_label(c, label_type='center', labels=[f'{val}' for val in df3[col]])
          # ax.bar_label(c, label_type='center', labels=[f'{val}\n({val / total[0] * 100.0:.1f}%)' for val in df3[col]])
        if r == 0 and column == 1:
          ax.legend(title='Plataforma', bbox_to_anchor=(0.8,1), loc='upper left')

        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-295-8ba202a07bde> in <module>
#      36           axes[r][column].set_visible(False)
#      37
# ---> 38         ax = df_list[count].plot(ax=axes[r,column], kind='barh', title=languages[r][column], width=0.8, log=True, figsize=(12,9), legend=False)
#      39
#      40         plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.4)
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

issues = ['Code Smells', 'Bugs', 'Vulnerabilidades']

# dataframe sample data
java = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
python = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
go = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
javascript = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)
typescript = pd.DataFrame(data={'Alura': [1266, 114, 18], 'Udacity': [6389, 328, 12]}, index=issues)

languages = [
              ['Java', 'Python'],
              ['Javascript', 'Typescript'],
              ['Go', '']
]

#define number of rows and columns for subplots
nrow=2
ncol=2

# make a list of all dataframes 
df_list = [java ,python, go, javascript,typescript]
fig, axes = plt.subplots(nrow, ncol)


# plot counter
count=0
for r in range(nrow):
    for column in range(ncol):
        print(r)
        print(column)

        ax = df_list[count].plot(ax=axes[r,column], kind='barh', title="a", width=0.8, log=True, figsize=(12,9), legend=False)
        plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.4)
        
        count+=1
        for row, c, col in zip(df3.index, ax.containers, df3.columns):
          ax.bar_label(c, label_type='center', labels=[f'{val}' for val in df3[col]])
          # ax.bar_label(c, label_type='center', labels=[f'{val}\n({val / total[0] * 100.0:.1f}%)' for val in df3[col]])
        if r == 0 and column == 1:
          ax.legend(title='Plataforma', bbox_to_anchor=(0.8,1), loc='upper left')

        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
# Out:
# 0
# 0
# 0
# 1
# 1
# 0
# 1
# 1
